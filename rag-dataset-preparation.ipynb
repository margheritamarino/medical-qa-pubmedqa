# %% [markdown]
# # PubMedQA: A Dataset for Biomedical Research Question Answering
#
# Group: TLDR
#
# * Federica Maria Laudizi
# * Francesca Visalli
# * Margherita Marino
# * Tomaz Maia Suller

# %% [markdown]
# This notebook computes embedding similarities and stores each question in the labelled dataset with its associated closest question in the artificial one. This dataset is used for RAG.

# %%
from collections import defaultdict
from pathlib import Path

import numpy as np
import pandas as pd

from utils import load

# %%
EMBEDDING_MODEL = "BioSentVec_PubMed_MIMICIII-bigram_d700"

EMBEDDING_BASE_DIR = Path("embeddings")
OUTPUT_DATA_DIR = Path("data")
SENTENCE_EMBEDDINGS_DIR = EMBEDDING_BASE_DIR / "sentence"

# %%
TARGET_SPLIT = "labeled"
SOURCE_SPLITS = (
    "artificial",
)

# %%
target_df = load("labeled")
target_df
# Out:
#         pubid                                           question  \
# 0    21645374  Do mitochondria play a role in remodelling lac...
# 1    16418930  Landolt C and snellen e acuity: differences in...
# 2     9488747  Syncope during bathing in infants, a pediatric...
# 3    17208539  Are the long-term results of the transanal pul...
# 4    10808977  Can tailored interventions increase mammograph...
# ..        ...                                                ...
# 995   8921484  Does gestational age misclassification explain...
# 996  16564683  Is there any interest to perform ultrasonograp...
# 997  23147106  Is peak concentration needed in therapeutic dr...
# 998  21550158  Can autologous platelet-rich plasma gel enhanc...
# 999  17559449  Are sugars-free medicines more erosive than su...
#
#                                            long_answer  final_decision  \
# 0    Results depicted mitochondrial dynamics in viv...            True
# 1    Using the charts described, there was only a s...           False
# 2    "Aquagenic maladies" could be a pediatric form...            True
# 3    Our long-term study showed significantly bette...           False
# 4    The effects of the intervention were most pron...            True
# ..                                                 ...             ...
# 995  Gestational age misclassification is an unlike...           False
# 996  Sonography has no place in the diagnosis of un...           False
# 997  These results suggest little need to use peak ...           False
# 998  The PRP group recorded reduced pain, swelling,...            True
# 999  Paediatric SF medicines were not more erosive ...           False
#
#                                       context.contexts  \
# 0    [Programmed cell death (PCD) is the regulated ...
# 1    [Assessment of visual acuity depends on the op...
# 2    [Apparent life-threatening events in infants a...
# 3    [The transanal endorectal pull-through (TERPT)...
# 4    [Telephone counseling and tailored print commu...
# ..                                                 ...
# 995  [After 34 weeks gestation, summary measures of...
# 996  [To evaluate the accuracy of ultrasonographic ...
# 997  [We analyzed the pharmacokinetic-pharmacodynam...
# 998  [This investigation assesses the effect of pla...
# 999  [The reduced use of sugars-containing (SC) liq...
#
#                                         context.labels  \
# 0                                [BACKGROUND, RESULTS]
# 1          [BACKGROUND, PATIENTS AND METHODS, RESULTS]
# 2                           [BACKGROUND, CASE REPORTS]
# 3                          [PURPOSE, METHODS, RESULTS]
# 4    [BACKGROUND, DESIGN, PARTICIPANTS, INTERVENTIO...
# ..                                                 ...
# 995                     [BACKGROUND, METHODS, RESULTS]
# 996         [OBJECTIVE, MATERIAL AND METHODS, RESULTS]
# 997                     [BACKGROUND, METHODS, RESULTS]
# 998           [PURPOSE, PATIENTS AND METHODS, RESULTS]
# 999                      [OBJECTIVE, METHODS, RESULTS]
#
#                                         context.meshes  \
# 0    [Alismataceae, Apoptosis, Cell Differentiation...
# 1    [Adolescent, Adult, Aged, Aged, 80 and over, A...
# 2    [Baths, Histamine, Humans, Infant, Syncope, Ur...
# 3    [Child, Child, Preschool, Colectomy, Female, H...
# 4    [Cost-Benefit Analysis, Female, Health Mainten...
# ..                                                 ...
# 995  [Adult, Australia, Birth Weight, Classificatio...
# 996  [Child, Child, Preschool, Cryptorchidism, Huma...
# 997  [Aged, Aged, 80 and over, Anti-Bacterial Agent...
# 998  [Adult, Bone Regeneration, Chi-Square Distribu...
# 999  [Child, Child, Preschool, Drug-Related Side Ef...
#
#      context.reasoning_required_pred  context.reasoning_free_pred  \
# 0                               True                         True
# 1                              False                        False
# 2                               True                         True
# 3                               True                        False
# 4                               True                        False
# ..                               ...                          ...
# 995                             True                        False
# 996                            False                        False
# 997                             True                        False
# 998                            False                         True
# 999                            False                        False
#
#     context.reasoning_required_pred_str context.reasoning_free_pred_str  \
# 0                                  True                            True
# 1                                 False                           False
# 2                                  True                            True
# 3                                  True                           False
# 4                                  True                           False
# ..                                  ...                             ...
# 995                                True                           False
# 996                               False                           False
# 997                                True                           False
# 998                               False                            True
# 999                               False                           False
#
#     final_decision_str
# 0                 True
# 1                False
# 2                 True
# 3                False
# 4                 True
# ..                 ...
# 995              False
# 996              False
# 997              False
# 998               True
# 999              False
#
# [1000 rows x 12 columns]

# %%
source_df = pd.concat([
    load(split)
    for split in SOURCE_SPLITS
]).reset_index()
source_df
# Out:
#          index     pubid                                           question  \
# 0            0  25429730  Are group 2 innate lymphoid cells ( ILC2s ) in...
# 1            1  25433161  Does vagus nerve contribute to the development...
# 2            2  25445714  Does psammaplin A induce Sirtuin 1-dependent a...
# 3            3  25431941  Is methylation of the FGFR2 gene associated wi...
# 4            4  25432519  Do tumor-infiltrating immune cell profiles and...
# ...        ...       ...                                                ...
# 211264  211264   8217974  Is urine production rate related to behavioura...
# 211265  211265   8204319  Does evaluation of the use of general practice...
# 211266  211266   8205673  Does intracoronary angiotensin-converting enzy...
# 211267  211267   8215873  Does transfusion significantly increase the ri...
# 211268  211268   8201088  Is low intramucosal pH associated with failure...
#
#                                               long_answer  final_decision  \
# 0       As ILC2s are elevated in patients with CRSwNP,...            True
# 1       Neuronal signals via the hepatic vagus nerve c...            True
# 2       PsA significantly inhibited MCF-7/adr cells pr...            True
# 3       We identified a novel biologically plausible c...            True
# 4       Breast cancer immune cell subpopulation profil...            True
# ...                                                   ...             ...
# 211264  During active sleep (state 2F) hourly fetal ur...            True
# 211265  General practice registers can provide a suita...            True
# 211266  Intracoronary enalaprilat resulted in an impro...            True
# 211267  The choice between splenectomy and splenic rep...            True
# 211268  Some critically ill patients with low gastric ...            True
#
#                                          context.contexts  \
# 0       [Chronic rhinosinusitis (CRS) is a heterogeneo...
# 1       [Phosphatidylethanolamine N-methyltransferase ...
# 2       [Psammaplin A (PsA) is a natural product isola...
# 3       [This study examined links between DNA methyla...
# 4       [Tumor microenvironment immunity is associated...
# ...                                                   ...
# 211264  [To investigate the relation between hourly fe...
# 211265  [This study set out to show how well samples f...
# 211266  [There is increasing recognition of myocardial...
# 211267  [To determine if splenectomy results in an inc...
# 211268  [To determine if low gastric intramucosal pH i...
#
#                                            context.labels  \
# 0               [BACKGROUND, OBJECTIVE, METHODS, RESULTS]
# 1                           [OBJECTIVE, METHODS, RESULTS]
# 2                                   [BACKGROUND, METHODS]
# 3                           [OBJECTIVE, METHODS, RESULTS]
# 4                          [BACKGROUND, METHODS, RESULTS]
# ...                                                   ...
# 211264  [OBJECTIVE, METHODS, METHODS, METHODS, METHODS...
# 211265                      [OBJECTIVE, METHODS, RESULTS]
# 211266                              [BACKGROUND, RESULTS]
# 211267  [OBJECTIVE, METHODS, METHODS, METHODS, METHODS...
# 211268  [OBJECTIVE, METHODS, METHODS, METHODS, METHODS...
#
#                                            context.meshes final_decision_str
# 0       [Adult, Aged, Antigens, Surface, Case-Control ...               True
# 1       [Animals, Chemokine CCL2, Diet, High-Fat, Dise...               True
# 2       [Acetylation, Animals, Antibiotics, Antineopla...               True
# 3                                                      []               True
# 4       [Adult, Aged, Anthracyclines, Antibodies, Mono...               True
# ...                                                   ...                ...
# 211264  [Behavior, Embryonic and Fetal Development, Fe...               True
# 211265  [Adult, Age Factors, Epidemiologic Methods, Fa...               True
# 211266  [Adult, Aged, Coronary Vessels, Diastole, Enal...               True
# 211267  [Adult, Bacteremia, Female, Humans, Injury Sev...               True
# 211268  [Achlorhydria, Aged, Blood Gas Analysis, Criti...               True
#
# [211269 rows x 9 columns]

# %%
embeddings: dict[str, dict[str, np.ndarray]] = defaultdict(dict)
for split in ("labeled", "unlabeled", "artificial"):
    with (SENTENCE_EMBEDDINGS_DIR / split / f"{EMBEDDING_MODEL}.npz").open("rb") as f:
        with np.load(f) as data:
            for key, value in data.items():
                embeddings[split][key] = value
embeddings
# Out:
# defaultdict(dict,
#             {'labeled': {'question': array([[-0.03413809,  0.08783249,  0.23454772, ...,  0.18894325,
#                       -0.07009058, -0.05960368],
#                      [-0.01844016, -0.19973463, -0.27306175, ...,  0.1554322 ,
#                        0.01059111,  0.09929473],
#                      [-0.29999515, -0.5277951 , -0.4147372 , ...,  0.10904694,
#                        0.10407549,  0.25947914],
#                      ...,
#                      [-0.21563652, -0.11012568,  0.24946418, ...,  0.09730155,
#                       -0.04870246,  0.13552524],
#                      [ 0.05309517,  0.21788427, -0.34573796, ..., -0.2428476 ,
#                        0.18243514,  0.0655036 ],
#                      [ 0.30908936,  0.43286923, -0.03107509, ..., -0.11518667,
#                        0.11042855,  0.41196337]], shape=(1000, 700), dtype=float32),
#               'long_answer': array([[ 0.05308781,  0.17729971,  0.06652988, ...,  0.06373439,
#                       -0.05955856,  0.0458597 ],
#                      [ 0.14479405,  0.11211748, -0.14160298, ...,  0.0012208 ,
#                       -0.08160637,  0.04779994],
#                      [ 0.16576943,  0.1947694 , -0.22068433, ..., -0.19659024,
#                        0.30638075,  0.14782251],
#                      ...,
#                      [-0.28397858, -0.25365204, -0.00788738, ...,  0.21379957,
#                       -0.16373147,  0.26534417],
#                      [-0.00723498, -0.04412904, -0.18016483, ..., -0.14617576,
#                        0.06766817,  0.20654573],
#                      [ 0.28509697, -0.06700175, -0.29933342, ..., -0.04602502,
#                        0.14278011,  0.31169072]], shape=(1000, 700), dtype=float32),
#               'context.full_context': array([[ 0.03543562,  0.06339458, -0.01813725, ...,  0.03087878,
#                       -0.03121674, -0.02522825],
#                      [ 0.00939474,  0.09034648, -0.1803936 , ...,  0.0184396 ,
#                       -0.04612975, -0.00963973],
#                      [ 0.14484449, -0.05286528, -0.12720461, ...,  0.03248279,
#                       -0.00811869,  0.07979749],
#                      ...,
#                      [-0.25908   , -0.09438125,  0.08165109, ...,  0.0255773 ,
#                       -0.04560834,  0.22037196],
#                      [-0.05104896, -0.04999701, -0.17334136, ..., -0.16368811,
#                       -0.03574447,  0.09776458],
#                      [ 0.26769122,  0.01255817, -0.11792345, ...,  0.07444169,
#                       -0.00084501,  0.20016265]], shape=(1000, 700), dtype=float32),
#               'context.full_meshes': array([[ 0.14354752,  0.02825082,  0.12641177, ...,  0.16319792,
#                       -0.1369054 ,  0.1687494 ],
#                      [ 0.13462967,  0.1378989 , -0.1045863 , ..., -0.02427642,
#                       -0.10043369,  0.03391398],
#                      [ 0.34586808, -0.26648673, -0.01296881, ...,  0.01853216,
#                        0.04437547,  0.33095637],
#                      ...,
#                      [-0.10086681,  0.03334048,  0.00064121, ...,  0.10280811,
#                       -0.12433095,  0.07252375],
#                      [ 0.02528978,  0.02030561, -0.13594417, ..., -0.04123871,
#                        0.04190862,  0.13301253],
#                      [ 0.1595049 , -0.00537947, -0.0572465 , ...,  0.06190928,
#                       -0.04227871,  0.18364832]], shape=(1000, 700), dtype=float32),
#               'full_text': array([[ 0.04646034,  0.08843502,  0.01564652, ...,  0.04471808,
#                       -0.04252835, -0.00510601],
#                      [ 0.03999874,  0.08608016, -0.16811746, ...,  0.01407954,
#                       -0.05588683,  0.00614129],
#                      [ 0.13062184, -0.07122019, -0.14266208, ...,  0.01840496,
#                        0.02195564,  0.10780544],
#                      ...,
#                      [-0.22801805, -0.08311979,  0.06522635, ...,  0.07118613,
#                       -0.07790952,  0.18600614],
#                      [-0.02939626, -0.02819897, -0.1753096 , ..., -0.14619078,
#                       -0.00379783,  0.11284218],
#                      [ 0.25509232,  0.01324665, -0.11968232, ...,  0.05804599,
#                        0.00674669,  0.20888004]], shape=(1000, 700), dtype=float32),
#               'no_reasoning': array([[ 4.0717442e-02,  6.2824614e-02, -1.6461810e-04, ...,
#                        4.2728867e-02, -3.4688707e-02, -2.1541916e-02],
#                      [ 2.6682729e-02,  8.3636969e-02, -1.7103849e-01, ...,
#                        1.7115530e-02, -5.2879095e-02,  1.3842790e-03],
#                      [ 1.2855142e-01, -9.4460569e-02, -1.3637303e-01, ...,
#                        3.3938233e-02,  1.0861198e-03,  1.0271734e-01],
#                      ...,
#                      [-2.2092892e-01, -6.1173074e-02,  7.4089199e-02, ...,
#                        5.3130489e-02, -6.5505631e-02,  1.7925401e-01],
#                      [-3.3414084e-02, -2.6965884e-02, -1.7416710e-01, ...,
#                       -1.4513692e-01, -1.1664493e-02,  1.0334966e-01],
#                      [ 2.5212222e-01,  2.0407222e-02, -1.0631661e-01, ...,
#                        6.6360623e-02, -4.1909115e-03,  2.0135100e-01]],
#                     shape=(1000, 700), dtype=float32)},
#              'unlabeled': {'question': array([[ 0.06884149,  0.09253303, -0.00933789, ...,  0.00751946,
#                        0.28893805,  0.57510984],
#                      [ 0.11924087,  0.09481722, -0.30673236, ..., -0.17305955,
#                        0.00238429,  0.26650056],
#                      [ 0.0383376 ,  0.31888318, -0.17162542, ...,  0.13429376,
#                        0.11657157, -0.16360204],
#                      ...,
#                      [-0.13140568, -0.04451188, -0.39679727, ...,  0.17834793,
#                        0.09197363, -0.01045586],
#                      [ 0.05883621,  0.21314985, -0.0990895 , ..., -0.19755957,
#                       -0.12729292,  0.07575452],
#                      [ 0.12698324,  0.24744143, -0.16070795, ..., -0.07825168,
#                        0.07890131,  0.0306293 ]], shape=(61249, 700), dtype=float32),
#               'long_answer': array([[ 0.12406418,  0.28102055, -0.24398802, ..., -0.14998546,
#                        0.1286896 ,  0.26695687],
#                      [-0.00373895,  0.11701161, -0.17880164, ..., -0.06039822,
#                       -0.02701686,  0.040082  ],
#                      [ 0.13105251,  0.0814584 , -0.02514648, ...,  0.06406018,
#                        0.30219647,  0.01280487],
#                      ...,
#                      [ 0.09547907,  0.03935905, -0.24877533, ...,  0.07568425,
#                        0.12282981, -0.0217843 ],
#                      [ 0.08787141,  0.15125416, -0.03801714, ..., -0.210507  ,
#                       -0.12833229, -0.06645609],
#                      [ 0.22240093,  0.13905549, -0.4246805 , ...,  0.12331058,
#                       -0.00470235, -0.0825434 ]], shape=(61249, 700), dtype=float32),
#               'context.full_context': array([[ 0.12456208,  0.09302846, -0.13409257, ..., -0.00369093,
#                        0.0461846 ,  0.05894447],
#                      [ 0.03352959,  0.04404639, -0.08806867, ..., -0.04793481,
#                        0.06241158,  0.05713638],
#                      [ 0.09033377,  0.07355819, -0.10152893, ..., -0.03904848,
#                        0.12525104, -0.07994368],
#                      ...,
#                      [ 0.10909243,  0.06105228, -0.18969648, ..., -0.04892434,
#                       -0.01659807, -0.08097282],
#                      [ 0.07677945,  0.12679142,  0.00342426, ..., -0.03721555,
#                        0.02186594, -0.04909003],
#                      [ 0.11308477,  0.00776527, -0.27746317, ...,  0.05928028,
#                        0.02216845,  0.00162403]], shape=(61249, 700), dtype=float32),
#               'context.full_meshes': array([[ 0.15522955,  0.19233708, -0.15835342, ..., -0.06284791,
#                       -0.04895317,  0.15367934],
#                      [-0.01760954,  0.00166879, -0.11004161, ..., -0.05829111,
#                        0.12074392, -0.05814334],
#                      [ 0.10918792,  0.21206744,  0.00876861, ...,  0.12776472,
#                       -0.04035899,  0.04628901],
#                      ...,
#                      [ 0.10510525,  0.10950001, -0.07748939, ..., -0.01727518,
#                       -0.03340608, -0.08919056],
#                      [ 0.01290933,  0.0939059 ,  0.04108579, ..., -0.08563209,
#                       -0.01687063,  0.01349744],
#                      [ 0.21605565, -0.00698162, -0.15357101, ...,  0.07803568,
#                        0.08522267, -0.09164228]], shape=(61249, 700), dtype=float32),
#               'full_text': array([[ 0.13065197,  0.11439779, -0.14049646, ..., -0.01923288,
#                        0.04054342,  0.09974076],
#                      [ 0.02575212,  0.05201586, -0.10747612, ..., -0.0526481 ,
#                        0.05299406,  0.04724525],
#                      [ 0.09167178,  0.09204952, -0.08891474, ..., -0.01270053,
#                        0.12791826, -0.06603765],
#                      ...,
#                      [ 0.09897002,  0.05969175, -0.19065271, ..., -0.01929691,
#                        0.00557917, -0.06964131],
#                      [ 0.06340855,  0.12972395,  0.00085346, ..., -0.0730164 ,
#                       -0.00695764, -0.03168035],
#                      [ 0.13567732,  0.02961167, -0.27256602, ...,  0.05952201,
#                        0.02895259, -0.01938819]], shape=(61249, 700), dtype=float32),
#               'no_reasoning': array([[ 0.12945715,  0.10936881, -0.13449608, ..., -0.01356351,
#                        0.03692475,  0.09167769],
#                      [ 0.03122303,  0.03728226, -0.09594464, ..., -0.05157424,
#                        0.06712834,  0.04835529],
#                      [ 0.08819262,  0.09457969, -0.0960236 , ..., -0.01932935,
#                        0.11247525, -0.0740476 ],
#                      ...,
#                      [ 0.09826281,  0.06233894, -0.18298005, ..., -0.03579968,
#                       -0.01626316, -0.07678159],
#                      [ 0.06251899,  0.1257121 ,  0.001377  , ..., -0.0575102 ,
#                        0.00399146, -0.02792072],
#                      [ 0.12739089,  0.01886938, -0.2537111 , ...,  0.04917371,
#                        0.03340116, -0.01011285]], shape=(61249, 700), dtype=float32)},
#              'artificial': {'question': array([[-0.1214024 ,  0.27876955, -0.5093286 , ..., -0.0653001 ,
#                        0.35656112,  0.30957347],
#                      [ 0.23658836,  0.04482324, -0.01932252, ...,  0.03254955,
#                       -0.14254974,  0.00363447],
#                      [ 0.14960657,  0.2630486 ,  0.08287945, ...,  0.10566468,
#                       -0.05752607,  0.05183413],
#                      ...,
#                      [ 0.13443741, -0.07429843,  0.01822976, ...,  0.18290776,
#                        0.08340807,  0.03780341],
#                      [ 0.3574917 , -0.19434132, -0.34923545, ...,  0.34213582,
#                        0.03375815,  0.02745426],
#                      [ 0.30500406,  0.16730738,  0.13664018, ..., -0.17198727,
#                       -0.05564419,  0.04343373]], shape=(211269, 700), dtype=float32),
#               'long_answer': array([[-0.04921082,  0.30795774, -0.22850601, ..., -0.11085527,
#                        0.16390054,  0.20640221],
#                      [ 0.37538442,  0.13373499,  0.08156921, ..., -0.06785042,
#                        0.0411521 , -0.06275005],
#                      [ 0.08146029,  0.13884252, -0.00231314, ...,  0.04717191,
#                       -0.01186363,  0.0555006 ],
#                      ...,
#                      [ 0.15179747, -0.06775388, -0.01359888, ..., -0.0736155 ,
#                        0.16219895,  0.01494752],
#                      [-0.00485217, -0.10725535, -0.21366912, ...,  0.03875251,
#                        0.051946  ,  0.01767121],
#                      [ 0.04213631,  0.06285334,  0.01904362, ..., -0.14354756,
#                       -0.08150575,  0.22686853]], shape=(211269, 700), dtype=float32),
#               'context.full_context': array([[ 0.02163555,  0.1947242 , -0.17652261, ..., -0.12525216,
#                        0.14375977,  0.14755501],
#                      [ 0.09512381,  0.04641293, -0.02680976, ..., -0.02530365,
#                       -0.04149237,  0.10304604],
#                      [ 0.15476733,  0.2602273 , -0.0801094 , ...,  0.01473422,
#                       -0.10639503,  0.22866446],
#                      ...,
#                      [ 0.13639425, -0.02797919, -0.00583292, ..., -0.01538496,
#                       -0.01281202, -0.0618848 ],
#                      [ 0.07902367,  0.00437972, -0.14258549, ..., -0.01574242,
#                        0.05455273, -0.02790036],
#                      [ 0.13153705,  0.11135171, -0.09320383, ..., -0.10760871,
#                       -0.07980643,  0.14725961]], shape=(211269, 700), dtype=float32),
#               'context.full_meshes': array([[-0.08029711, -0.01446153, -0.12018452, ..., -0.07887861,
#                       -0.01639762,  0.12388996],
#                      [ 0.05678417,  0.17526646, -0.05552769, ..., -0.02534453,
#                        0.01195014,  0.16487372],
#                      [-0.1270397 ,  0.12179545, -0.03281877, ..., -0.05805086,
#                       -0.13994874,  0.14560303],
#                      ...,
#                      [ 0.2508809 , -0.00133369,  0.42367345, ...,  0.00966556,
#                       -0.02824616,  0.00878647],
#                      [-0.02201549, -0.11270179, -0.14915898, ...,  0.00699114,
#                       -0.08246676,  0.09647275],
#                      [ 0.06231007, -0.09750223, -0.0309901 , ...,  0.00481364,
#                       -0.03945677,  0.20166634]], shape=(211269, 700), dtype=float32),
#               'full_text': array([[-0.00479869,  0.182581  , -0.18844976, ..., -0.11320306,
#                        0.13177823,  0.15832873],
#                      [ 0.11821024,  0.07054456, -0.02101681, ..., -0.02390636,
#                       -0.03392243,  0.09293078],
#                      [ 0.06065191,  0.18323833, -0.02539335, ...,  0.01422214,
#                       -0.07669193,  0.13235876],
#                      ...,
#                      [ 0.14675404, -0.03312806,  0.02538787, ..., -0.01243096,
#                        0.0104538 , -0.04476508],
#                      [ 0.06257252, -0.03196436, -0.15788035, ...,  0.00607273,
#                        0.03348964, -0.00370837],
#                      [ 0.12065759,  0.06298785, -0.05880241, ..., -0.08862936,
#                       -0.06808811,  0.15857315]], shape=(211269, 700), dtype=float32),
#               'no_reasoning': array([[ 0.00123731,  0.16328982, -0.18156892, ..., -0.11446871,
#                        0.12610804,  0.15203236],
#                      [ 0.09864575,  0.0654459 , -0.03016346, ..., -0.02115991,
#                       -0.03957103,  0.10440432],
#                      [ 0.04555205,  0.20607656, -0.05212676, ..., -0.00156094,
#                       -0.11126976,  0.17399445],
#                      ...,
#                      [ 0.14648296, -0.028363  ,  0.02889182, ..., -0.00336101,
#                       -0.00974238, -0.05246636],
#                      [ 0.07257357, -0.02193903, -0.15017416, ...,  0.00331136,
#                        0.0311795 , -0.00693853],
#                      [ 0.12518647,  0.06465477, -0.06550454, ..., -0.08355201,
#                       -0.06878817,  0.1546257 ]], shape=(211269, 700), dtype=float32)}})

# %%
[key for key in embeddings["labeled"].keys()]
# Out:
# ['question',
#  'long_answer',
#  'context.full_context',
#  'context.full_meshes',
#  'full_text',
#  'no_reasoning']

# %%
source_embeddings = np.vstack(
    [embeddings[split]["full_text"] for split in SOURCE_SPLITS],
)
source_embeddings
# Out:
# array([[-0.00479869,  0.182581  , -0.18844976, ..., -0.11320306,
#          0.13177823,  0.15832873],
#        [ 0.11821024,  0.07054456, -0.02101681, ..., -0.02390636,
#         -0.03392243,  0.09293078],
#        [ 0.06065191,  0.18323833, -0.02539335, ...,  0.01422214,
#         -0.07669193,  0.13235876],
#        ...,
#        [ 0.14675404, -0.03312806,  0.02538787, ..., -0.01243096,
#          0.0104538 , -0.04476508],
#        [ 0.06257252, -0.03196436, -0.15788035, ...,  0.00607273,
#          0.03348964, -0.00370837],
#        [ 0.12065759,  0.06298785, -0.05880241, ..., -0.08862936,
#         -0.06808811,  0.15857315]], shape=(211269, 700), dtype=float32)

# %%
source_norms = np.linalg.norm(source_embeddings, axis=1).reshape((-1, 1))
normalised_source_embeddings = source_embeddings / source_norms
normalised_source_embeddings
# Out:
# array([[-0.00165882,  0.06311502, -0.06514375, ..., -0.0391323 ,
#          0.0455534 ,  0.05473144],
#        [ 0.03776748,  0.02253857, -0.00671475, ..., -0.00763794,
#         -0.01083802,  0.02969084],
#        [ 0.02055335,  0.06209468, -0.00860514, ...,  0.00481951,
#         -0.02598889,  0.04485292],
#        ...,
#        [ 0.06021097, -0.01359194,  0.01041626, ..., -0.00510023,
#          0.00428904, -0.01836644],
#        [ 0.02458053, -0.01255664, -0.06202055, ...,  0.00238557,
#          0.01315582, -0.00145677],
#        [ 0.04316441,  0.02253346, -0.02103615, ..., -0.03170653,
#         -0.02435805,  0.05672844]], shape=(211269, 700), dtype=float32)

# %%
target_embeddings = embeddings["labeled"]["full_text"]
target_norms = np.linalg.norm(target_embeddings, axis=1).reshape((-1, 1))
normalised_target_embeddings = target_embeddings / target_norms
normalised_target_embeddings
# Out:
# array([[ 0.01749045,  0.03329223,  0.00589029, ...,  0.01683456,
#         -0.01601021, -0.00192221],
#        [ 0.01270052,  0.02733243, -0.05338116, ...,  0.00447058,
#         -0.01774536,  0.00195   ],
#        [ 0.04961868, -0.02705407, -0.05419235, ...,  0.0069914 ,
#          0.00834018,  0.04095153],
#        ...,
#        [-0.06857593, -0.02499809,  0.01961668, ...,  0.02140907,
#         -0.02343112,  0.05594094],
#        [-0.01125871, -0.01080015, -0.06714322, ..., -0.05599077,
#         -0.00145456,  0.04321832],
#        [ 0.09861822,  0.00512113, -0.04626896, ...,  0.02244047,
#          0.00260826,  0.08075263]], shape=(1000, 700), dtype=float32)

# %%
embedding_similarities: np.ndarray = normalised_target_embeddings @ normalised_source_embeddings.T
embedding_similarities
# Out:
# array([[0.48322773, 0.52042145, 0.5706818 , ..., 0.45885706, 0.45454654,
#         0.40899062],
#        [0.44100472, 0.36688218, 0.361651  , ..., 0.48534036, 0.44923443,
#         0.44422936],
#        [0.5663876 , 0.4687558 , 0.38878846, ..., 0.54912317, 0.5876865 ,
#         0.5840443 ],
#        ...,
#        [0.48836172, 0.41253626, 0.4843232 , ..., 0.5285813 , 0.57625914,
#         0.50031507],
#        [0.5431512 , 0.44224215, 0.43224412, ..., 0.5576449 , 0.59722626,
#         0.5158511 ],
#        [0.49003065, 0.4559083 , 0.45115662, ..., 0.5565902 , 0.5234872 ,
#         0.6632899 ]], shape=(1000, 211269), dtype=float32)

# %%
closest_source = embedding_similarities.argmax(axis=1)
closest_source
# Out:
# array([209582, 174144, 173931,  22648, 169075, 176824, 203394,  17016,
#        164601,  91343,  66484, 167535,  52064, 122742,  92317, 138222,
#         28890, 174982, 106129, 123157,  24857,  91474,  45710, 205535,
#         39463, 164166,   5512,  31243, 136861,  82171,  57230,  95950,
#        100740,  61170,  94462, 108867,  42459,  48701,  81270,  67156,
#         81028,  79761, 192572, 149140, 103877, 114089, 135803,  10478,
#         88240, 170125,  48030, 150469, 135893, 179734, 187534, 160450,
#         20542, 209438, 153209,   1319,    213, 103296,  86494,  91499,
#        150023,  50728, 156451, 163893, 155215,  77214,  69401, 178277,
#        144804, 131771, 158081, 178447,  30472, 201755,  15954, 137073,
#         82062, 162682,  73521, 172289,  29943,  39577, 122567, 107415,
#          5663,  66785,  53796, 179924, 115997,  39952,  42035,  42063,
#        127860, 149997,   3032, 162759,  57133,  79680, 202033, 151748,
#        180542, 199547, 147835,  92471, 175526, 198814, 179804, 104047,
#         19382, 100220, 148624,  22641,  11486, 169361,  24857,  82068,
#        111504, 188453,  31183,   2614, 121644, 115140, 165868, 165749,
#         54580,  69898, 127942,  44931, 202672, 110971, 122759, 207103,
#        101227, 203104, 191402, 204139,  58605,  89128, 176881, 184800,
#        156668,  13767,  32946, 104008,  91585,  71289, 124508,  56016,
#        140028, 209596,  14278,  15138, 145301, 119667, 146350, 188222,
#         28993,  30777, 131008, 146243, 205164,  14441,  37154, 204006,
#        185433, 163259,  85797,  73302, 147107, 118103, 124485,  71392,
#        203166,  99852,  74556,    301,   7859, 205235,  93576,  50852,
#         48077, 101734,  59155, 184815,  10605,  41799, 104825, 104195,
#        169760,  55610, 193828,  44434, 108533, 167965, 144529,  87457,
#        180681,  87890, 150600,   3249,   5947,  54255,  84457, 185247,
#         48250,  52933, 180337,  76172, 135188,  76807, 208830, 208084,
#        170211, 198444, 134500,  97394, 104582,  68446, 119759, 164124,
#        150346,   1299, 127161, 142623,  23026, 177003, 112016, 132642,
#         91498, 149956,  80418, 169962,  28974, 124032,  32758, 128526,
#        170561,  91845,  45277, 176474,   2796,  64615, 199573, 127431,
#        165040, 164453,  97232, 164617,  31899,  21942, 159038,  39416,
#        112765,  67919,   1802, 173849, 162844,  78385, 205235,  17653,
#         98356, 100397, 102281, 159217,   6476, 174558, 188368, 187360,
#         35266, 109799, 127161,  77599, 143325, 118772,  10592, 143662,
#        136860,  57245, 125002,  82319,  95520,  97635,  17793,  62047,
#         66447, 136054,  95251, 197003,   6013,  42486, 106301, 101227,
#        150997,  87984,   6675,  80804, 131492, 157751,  57180, 172306,
#        123157,  49209,  63042,  78484,  87538,  39305,  58821, 173784,
#        181652, 149566,  34328,  93225, 165319,  81606,  62567,  99020,
#        122741,  89387,  52719, 143121,  13190,  70846, 130378, 164204,
#        190419, 168684, 195523, 101431, 195893,  92317, 181295, 138574,
#         27074,   4188, 185916,  38582,  23085,  64462, 206910, 210845,
#         16855,  80735, 109112,   2911, 184784,  51257,  57005,  88141,
#         44408, 149447, 203261, 139756, 159134,  92546,  14154,  21345,
#         27420,  64627,  26595,  82079, 107807,  94680, 203261,  42658,
#         12766,  38602,  43233, 149363,  50208, 113446, 156801, 201454,
#         75829,  46112, 115406, 108173,  21930,  97005,  38153, 142567,
#        127936,  88449, 196126, 194696, 114817,  75632, 191937, 178684,
#         70569,  48369,  48644, 195095,   8436,  41794,  81116,  81553,
#        124110,  19988, 111435, 129280, 168630, 115807,  70951,  46046,
#        193820, 116802, 125002,  14145,  30117,  42523,  54517, 108037,
#        194274,  62809, 119425, 128085, 155974, 129790,   7296, 174368,
#        184060,  13704, 118014, 174587, 203926,   6479,  57206, 155206,
#        195833, 183572, 119948, 102761,   5968, 144847,  76761,  46056,
#         58288,  18038,  98133, 126563, 183384,  78478,  16219,  50340,
#        135422, 116606, 176235,  65162, 118200,  93490, 116153, 138776,
#        122445, 148446,   5241,  76270, 171198, 139097, 155434,  20501,
#         82288,  21573,  58856, 102963,  57415, 106294, 141523,  10797,
#        208354,  70434,  74248, 201116, 193027,  17604, 158180, 152875,
#        120174, 104057,  22433,  32119,  28236, 177009, 116274, 158229,
#        134616, 157650,  96809, 177132,  11636, 174511, 135423,   8571,
#        111536,  75824, 132048, 145613, 149485,  80177,  16079,  40616,
#        154836,  98343, 163311, 164832, 154523,   9482,  51930, 143210,
#        110747, 141345,   9671, 193006,  36258,  43017, 143330,  26698,
#        134866, 184587,  72984, 169227, 117138,  25346, 130772, 203210,
#         30362,  84787,  95699, 190491, 166689,  84457, 169887,  58881,
#        191937,  16280,   6037,  96064, 198502, 209022, 182455,  71338,
#        151252, 140940,  94741,  97949,  45626,  48939,  11070, 192796,
#         12221,   6416,  11766, 168797, 124777,  99084,  14371, 152717,
#        120051, 132868,   6882, 173034,  48993,  13883, 193897, 159320,
#         15480, 111400,  15939,  84524, 185791,  15480,  83238, 125200,
#         82139, 165584, 177034,  55247,  60523, 151849,   1506, 176740,
#          9100,  73384,  98696,  46913,  72048,  18182,  15338, 187223,
#         13392,  40072,  19988, 159356,  49201,  75233, 200799, 191479,
#         98112,  12933,  84548, 171252, 163685,  99796,  22775, 141111,
#        172982,  60102, 175816,  23130,  20605, 140155, 164395,  51730,
#         49507,  16077,  60102,  67308,  81746, 121242, 129032, 135188,
#        211152, 103014, 164124,  95069,  84684, 201240, 188500, 131672,
#        101903,  38090,  94380, 166633, 129403,  69439,  34612,  69088,
#        121984,  31885,  71916, 201914,   8169, 115600, 130745, 142338,
#        164166,  72611, 120307, 192702,  79761,  28344, 114369,  89607,
#        204780,  35620, 175782, 188343,  17344, 143897, 152497,  71628,
#        178570,  90152, 143880, 196518,  77060, 201339, 101332,  15588,
#         83057,  70778,  82524, 126466, 207950, 195386, 205500,  65052,
#         61910, 108173,  61090,  82007,  48967,  33671,  87461, 155241,
#        174676, 202824,  73966,  11886, 133567,   9740,  78522,  35194,
#        110982,  59503,  57081, 132031, 123423, 155604,  51297, 132416,
#         30145, 100147,  32218,  64282,  71802,  30383, 141169,  82408,
#        156336, 151061,  59364,  37582, 163847, 128391, 209417, 191851,
#        139462, 123792,  63339,  91343,  25509, 121311, 112283, 170715,
#         22602,  46727,  11924,  97417, 137002,  88478,  10066, 140187,
#         80962, 208834, 189320, 152994,  45571,  79187,  38153,  94900,
#        199967,  86964,  19161, 178466, 114174,  59216,  17583,  74344,
#         35376,   7611, 186517,  59189, 192187,  99819, 160424,  12441,
#        172516,  14231,  78025, 143237,  72642,  62643, 127190, 206301,
#          8344,  32314, 113742, 143942,  60881,  86511, 156668,  84977,
#        125710,  11446,  33334,  31529,  34885,  60501, 102334,  28591,
#         35942,  56724,  18604, 161851,   9637,  35447,  59026,  21870,
#        129509, 149121, 147574,  40890,  83405, 163643,  93017, 177661,
#        148215, 117113, 192699,  59975, 198783, 169093, 152570,  52927,
#        100519, 114168,  50107, 122527, 137869, 109252, 175248, 123093,
#         19246, 172226, 104607, 105065, 164476, 147763, 209103, 177221,
#        178053, 184114, 118907,  46174, 104146,  15658, 206080,  33334,
#         26461,   5782, 143539, 122587,  17759,   4480, 115440, 174417,
#        163011, 171931,  87593,  31711, 188688,   6112, 205391,  78692,
#        208033,  91411,  97539, 101049, 140834, 189461, 140567,  79643,
#        138249, 130791, 196774,  55260, 192995, 178104, 170321, 114757,
#        149288, 167260, 126826,  31895, 170085,  84381,    448, 179010,
#        196403,   8321, 174549, 163511,  52839, 133947, 112662,  40223,
#        203337,  41083,  10996, 179308, 104454, 204635,  46322,  63616,
#        162625,  63936,  87134, 165220,  72495, 175734,  37692, 159955,
#         52460,  77426, 150516, 148746, 112149, 188665,   8282,   2911,
#        198545, 122042,  80176, 139398, 115552, 161752, 133434,  52820,
#        169253,  10397,  37110,  71107, 132637,  25072,  37423, 108713,
#         81919, 165600, 164048, 104582,  62139,  36308,  32058, 150089,
#        125949, 142987, 119231,  69943, 126015, 207266,  87830,  80855,
#         44408,  67390,  83381, 175498, 167358,  98815, 160010,  51656,
#        180927,  12873, 209167, 136224, 163914, 155421,  32088, 101577,
#        143159,  61170, 186312, 200025, 195528,  18377, 157042, 102164,
#        166893, 199027,   8513,  64496,  19310, 129584, 136460, 186544,
#         71838,  76943,  41971,  13670,  56292,  88716, 198590, 187704,
#        162735,  45477,  74983,  25295, 125653, 137284, 188428, 114717,
#        132285,  37891, 117920, 162849, 195454, 136165, 149618, 190849,
#        181239,  64483, 200293,  75635, 179180, 154067, 109953,  58827])

# %%
def format_abstract(series: pd.Series) -> dict:
    context = list(series["context.contexts"])
    labels = list(series["context.labels"])

    labels.append("conclusion")
    context.append(series["long_answer"])

    labels.append("question")
    context.append(series["question"])

    abstract = "\n\n".join(
        [
            f"{label.upper()}\n{context}"
            for label, context in zip(labels, context)
        ]
    )
    final_decision_str = "Yes" if series["final_decision"] else "No"
    abstract += f"\n\nANSWER: {final_decision_str}"
    return abstract

# %%
source_abstracts = source_df.apply(format_abstract, axis="columns")
source_abstracts
# Out:
# 0         BACKGROUND\nChronic rhinosinusitis (CRS) is a ...
# 1         OBJECTIVE\nPhosphatidylethanolamine N-methyltr...
# 2         BACKGROUND\nPsammaplin A (PsA) is a natural pr...
# 3         OBJECTIVE\nThis study examined links between D...
# 4         BACKGROUND\nTumor microenvironment immunity is...
#                                 ...
# 211264    OBJECTIVE\nTo investigate the relation between...
# 211265    OBJECTIVE\nThis study set out to show how well...
# 211266    BACKGROUND\nThere is increasing recognition of...
# 211267    OBJECTIVE\nTo determine if splenectomy results...
# 211268    OBJECTIVE\nTo determine if low gastric intramu...
# Length: 211269, dtype: object

# %%
print(source_abstracts.iloc[0])
# Out:
# BACKGROUND
# Chronic rhinosinusitis (CRS) is a heterogeneous disease with an uncertain pathogenesis. Group 2 innate lymphoid cells (ILC2s) represent a recently discovered cell population which has been implicated in driving Th2 inflammation in CRS; however, their relationship with clinical disease characteristics has yet to be investigated.
#
# OBJECTIVE
# The aim of this study was to identify ILC2s in sinus mucosa in patients with CRS and controls and compare ILC2s across characteristics of disease.
#
# METHODS
# A cross-sectional study of patients with CRS undergoing endoscopic sinus surgery was conducted. Sinus mucosal biopsies were obtained during surgery and control tissue from patients undergoing pituitary tumour resection through transphenoidal approach. ILC2s were identified as CD45(+) Lin(-) CD127(+) CD4(-) CD8(-) CRTH2(CD294)(+) CD161(+) cells in single cell suspensions through flow cytometry. ILC2 frequencies, measured as a percentage of CD45(+) cells, were compared across CRS phenotype, endotype, inflammatory CRS subtype and other disease characteristics including blood eosinophils, serum IgE, asthma status and nasal symptom score.
#
# RESULTS
# 35 patients (40% female, age 48 ± 17 years) including 13 with eosinophilic CRS (eCRS), 13 with non-eCRS and 9 controls were recruited. ILC2 frequencies were associated with the presence of nasal polyps (P = 0.002) as well as high tissue eosinophilia (P = 0.004) and eosinophil-dominant CRS (P = 0.001) (Mann-Whitney U). They were also associated with increased blood eosinophilia (P = 0.005). There were no significant associations found between ILC2s and serum total IgE and allergic disease. In the CRS with nasal polyps (CRSwNP) population, ILC2s were increased in patients with co-existing asthma (P = 0.03). ILC2s were also correlated with worsening nasal symptom score in CRS (P = 0.04).
#
# CONCLUSION
# As ILC2s are elevated in patients with CRSwNP, they may drive nasal polyp formation in CRS. ILC2s are also linked with high tissue and blood eosinophilia and have a potential role in the activation and survival of eosinophils during the Th2 immune response. The association of innate lymphoid cells in CRS provides insights into its pathogenesis.
#
# QUESTION
# Are group 2 innate lymphoid cells ( ILC2s ) increased in chronic rhinosinusitis with nasal polyps or eosinophilia?
#
# ANSWER: Yes

# %%
target_df["closest_abstract"] = source_abstracts[closest_source].to_list()
target_df
# Out:
#         pubid                                           question  \
# 0    21645374  Do mitochondria play a role in remodelling lac...
# 1    16418930  Landolt C and snellen e acuity: differences in...
# 2     9488747  Syncope during bathing in infants, a pediatric...
# 3    17208539  Are the long-term results of the transanal pul...
# 4    10808977  Can tailored interventions increase mammograph...
# ..        ...                                                ...
# 995   8921484  Does gestational age misclassification explain...
# 996  16564683  Is there any interest to perform ultrasonograp...
# 997  23147106  Is peak concentration needed in therapeutic dr...
# 998  21550158  Can autologous platelet-rich plasma gel enhanc...
# 999  17559449  Are sugars-free medicines more erosive than su...
#
#                                            long_answer  final_decision  \
# 0    Results depicted mitochondrial dynamics in viv...            True
# 1    Using the charts described, there was only a s...           False
# 2    "Aquagenic maladies" could be a pediatric form...            True
# 3    Our long-term study showed significantly bette...           False
# 4    The effects of the intervention were most pron...            True
# ..                                                 ...             ...
# 995  Gestational age misclassification is an unlike...           False
# 996  Sonography has no place in the diagnosis of un...           False
# 997  These results suggest little need to use peak ...           False
# 998  The PRP group recorded reduced pain, swelling,...            True
# 999  Paediatric SF medicines were not more erosive ...           False
#
#                                       context.contexts  \
# 0    [Programmed cell death (PCD) is the regulated ...
# 1    [Assessment of visual acuity depends on the op...
# 2    [Apparent life-threatening events in infants a...
# 3    [The transanal endorectal pull-through (TERPT)...
# 4    [Telephone counseling and tailored print commu...
# ..                                                 ...
# 995  [After 34 weeks gestation, summary measures of...
# 996  [To evaluate the accuracy of ultrasonographic ...
# 997  [We analyzed the pharmacokinetic-pharmacodynam...
# 998  [This investigation assesses the effect of pla...
# 999  [The reduced use of sugars-containing (SC) liq...
#
#                                         context.labels  \
# 0                                [BACKGROUND, RESULTS]
# 1          [BACKGROUND, PATIENTS AND METHODS, RESULTS]
# 2                           [BACKGROUND, CASE REPORTS]
# 3                          [PURPOSE, METHODS, RESULTS]
# 4    [BACKGROUND, DESIGN, PARTICIPANTS, INTERVENTIO...
# ..                                                 ...
# 995                     [BACKGROUND, METHODS, RESULTS]
# 996         [OBJECTIVE, MATERIAL AND METHODS, RESULTS]
# 997                     [BACKGROUND, METHODS, RESULTS]
# 998           [PURPOSE, PATIENTS AND METHODS, RESULTS]
# 999                      [OBJECTIVE, METHODS, RESULTS]
#
#                                         context.meshes  \
# 0    [Alismataceae, Apoptosis, Cell Differentiation...
# 1    [Adolescent, Adult, Aged, Aged, 80 and over, A...
# 2    [Baths, Histamine, Humans, Infant, Syncope, Ur...
# 3    [Child, Child, Preschool, Colectomy, Female, H...
# 4    [Cost-Benefit Analysis, Female, Health Mainten...
# ..                                                 ...
# 995  [Adult, Australia, Birth Weight, Classificatio...
# 996  [Child, Child, Preschool, Cryptorchidism, Huma...
# 997  [Aged, Aged, 80 and over, Anti-Bacterial Agent...
# 998  [Adult, Bone Regeneration, Chi-Square Distribu...
# 999  [Child, Child, Preschool, Drug-Related Side Ef...
#
#      context.reasoning_required_pred  context.reasoning_free_pred  \
# 0                               True                         True
# 1                              False                        False
# 2                               True                         True
# 3                               True                        False
# 4                               True                        False
# ..                               ...                          ...
# 995                             True                        False
# 996                            False                        False
# 997                             True                        False
# 998                            False                         True
# 999                            False                        False
#
#     context.reasoning_required_pred_str context.reasoning_free_pred_str  \
# 0                                  True                            True
# 1                                 False                           False
# 2                                  True                            True
# 3                                  True                           False
# 4                                  True                           False
# ..                                  ...                             ...
# 995                                True                           False
# 996                               False                           False
# 997                                True                           False
# 998                               False                            True
# 999                               False                           False
#
#     final_decision_str                                   closest_abstract
# 0                 True  BACKGROUND\nDevelopmentally regulated programm...
# 1                False  OBJECTIVE\nDetection of amblyopia in infants a...
# 2                 True  BACKGROUND\nUrticaria is the disease that has ...
# 3                False  OBJECTIVE\nThe purpose of the investigation wa...
# 4                 True  OBJECTIVE\nA randomized trial was conducted to...
# ..                 ...                                                ...
# 995              False  OBJECTIVE\nWe aimed to determine whether ethni...
# 996              False  OBJECTIVE\nAn inguinal sonogram often is obtai...
# 997              False  OBJECTIVE\nVancomycin is a common treatment fo...
# 998               True  OBJECTIVE\nLower third molar removal provides ...
# 999              False  OBJECTIVE\nA pH of more than 6 is required for...
#
# [1000 rows x 13 columns]

# %%
target_df.to_parquet(OUTPUT_DATA_DIR / "labeled.parquet")
